# %% [markdown]
# ## MLFlow Tracking server

# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://localhost:5000") #can give remote repo uri

# %%
mlflow.set_experiment("check local host connection")

with mlflow.start_run():
    mlflow.log_metric("test",1)
    mlflow.log_metric("abhi",2)
# Out:
# 2025/11/04 11:57:00 INFO mlflow.tracking.fluent: Experiment with name 'check local host connection' does not exist. Creating a new experiment.
# 🏃 View run sedate-shad-577 at: http://localhost:5000/#/experiments/473402508940199148/runs/d46b0ae2c2cb49298a8e5cddd77f1548
# 🧪 View experiment at: http://localhost:5000/#/experiments/473402508940199148

# %%
with mlflow.start_run():
    mlflow.log_metric("lord",1)
    mlflow.log_metric("abhi",2)
# Out:
# 🏃 View run legendary-fawn-672 at: http://localhost:5000/#/experiments/473402508940199148/runs/201743e888fb49ae88d5e1eaca42957b
# 🧪 View experiment at: http://localhost:5000/#/experiments/473402508940199148
